# %%
# %load_ext sql
# !pip install ipython-sql
# !pip install pymysql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# Requirement already satisfied: ipython-sql in /Users/laurengusikoski/opt/anaconda3/envs/sql_2020/lib/python3.7/site-packages (0.3.9)
# Requirement already satisfied: six in /Users/laurengusikoski/opt/anaconda3/envs/sql_2020/lib/python3.7/site-packages (from ipython-sql) (1.14.0)
# Requirement already satisfied: sqlalchemy>=0.6.7 in /Users/laurengusikoski/opt/anaconda3/envs/sql_2020/lib/python3.7/site-packages (from ipython-sql) (1.3.15)
# Requirement already satisfied: ipython-genutils>=0.1.0 in /Users/laurengusikoski/opt/anaconda3/envs/sql_2020/lib/python3.7/site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: sqlparse in /Users/laurengusikoski/opt/anaconda3/envs/sql_2020/lib/python3.7/site-packages (from ipython-sql) (0.3.1)
# Requirement already satisfied: ipython>=1.0 in /Users/laurengusikoski/opt/anaconda3/envs/sql_2020/lib/python3.7/site-packages (from ipython-sql) (7.13.0)
# Requirement already satisfied: prettytable in /Users/laurengusikoski/opt/anaconda3/envs/sql_2020/lib/python3.7/site-packages (from ipython-sql) (0.7.2)
# Requirement already satisfied: traitlets>=4.2 in /Users/laurengusikoski/opt/anaconda3/envs/sql_2020/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (4.3.3)
# Requirement already satisfied: appnope; sys_platform == "darwin" in /Users/laurengusikoski/opt/anaconda3/envs/sql_2020/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (0.1.0)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /Users/laurengusikoski/opt/anaconda3/envs/sql_2020/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (4.8.0)
# Requirement already satisfied: pickleshare in /Users/laurengusikoski/opt/anaconda3/envs/sql_2020/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (0.7.5)
# Requirement already satisfied: decorator in /Users/laurengusikoski/opt/anaconda3/envs/sql_2020/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (4.4.2)
# Requirement already satisfied: jedi>=0.10 in /Users/laurengusikoski/opt/anaconda3/envs/sql_2020/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (0.16.0)
# Requirement already satisfied: setuptools>=18.5 in /Users/laurengusikoski/opt/anaconda3/envs/sql_2020/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (46.1.3.post20200330)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/laurengusikoski/opt/anaconda3/envs/sql_2020/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (3.0.4)
# Requirement already satisfied: backcall in /Users/laurengusikoski/opt/anaconda3/envs/sql_2020/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (0.1.0)
# Requirement already satisfied: pygments in /Users/laurengusikoski/opt/anaconda3/envs/sql_2020/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (2.6.1)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/laurengusikoski/opt/anaconda3/envs/sql_2020/lib/python3.7/site-packages (from pexpect; sys_platform != "win32"->ipython>=1.0->ipython-sql) (0.6.0)
# Requirement already satisfied: parso>=0.5.2 in /Users/laurengusikoski/opt/anaconda3/envs/sql_2020/lib/python3.7/site-packages (from jedi>=0.10->ipython>=1.0->ipython-sql) (0.6.2)
# Requirement already satisfied: wcwidth in /Users/laurengusikoski/opt/anaconda3/envs/sql_2020/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=1.0->ipython-sql) (0.1.9)
# Requirement already satisfied: pymysql in /Users/laurengusikoski/opt/anaconda3/envs/sql_2020/lib/python3.7/site-packages (0.9.3)

# %%
# %sql mysql://USERNAME:PASSWORD@HOST/DATABASE
# Out:
# 'Connected: admin@sql_project'

# %% [markdown]
# ## Exploratory Query 1

# %% [markdown]
# First exploratory SQL query:
#
# How did the interest and popularity of a music genre change over the past 5 years? (2015-2020)? We will use data from Google Trends API on 9 various music genres.
#
#
# To combine the 9 genre interest tables, we will create a VIEW so that we can run the query one time rather than 9 times for each genre. We will use UNION to merge the tables together.

# %%
# %%sql
# CREATE VIEW genre_interest AS
#     SELECT `date`, interest, "alternative" AS genre
#     FROM alternative_interest
#     UNION
#     SELECT `date`, interest, "folk" AS genre
#     FROM folk_interest
#     UNION
#     SELECT `date`, interest, "jazz" AS genre
#     FROM jazz_interest
#     UNION
#     SELECT `date`, interest, "pop" AS genre
#     FROM pop_interest
#     UNION
#     SELECT `date`, interest, "rap" AS genre
#     FROM rap_interest
#     UNION
#     SELECT `date`, interest, "reggae" AS genre
#     FROM reggae_interest
#     UNION
#     SELECT `date`, interest, "rnb" AS genre
#     FROM rnb_interest
#     UNION
#     SELECT `date`, interest, "rock" AS genre
#     FROM rock_interest
#     UNION
#     SELECT `date`, interest, "soul" AS genre
#     FROM soul_interest;
# Out:
#  * mysql://admin:***@lmu-sql.c8zmikzpsjej.us-east-2.rds.amazonaws.com/sql_project
# 0 rows affected.
# []

# %% [markdown]
# Confirming the view works as proposed:

# %%
# %%sql
# SELECT *
# FROM genre_interest
# Out:
#  * mysql://admin:***@lmu-sql.c8zmikzpsjej.us-east-2.rds.amazonaws.com/sql_project
# 2349 rows affected.
# [('2015-05-03', 83, 'alternative'),
#  ('2015-05-10', 86, 'alternative'),
#  ('2015-05-17', 83, 'alternative'),
#  ('2015-05-24', 84, 'alternative'),
#  ('2015-05-31', 88, 'alternative'),
#  ('2015-06-07', 81, 'alternative'),
#  ('2015-06-14', 78, 'alternative'),
#  ('2015-06-21', 81, 'alternative'),
#  ('2015-06-28', 90, 'alternative'),
#  ('2015-07-05', 89, 'alternative'),
#  ('2015-07-12', 89, 'alternative'),
#  ('2015-07-19', 100, 'alternative'),
#  ('2015-07-26', 82, 'alternative'),
#  ('2015-08-02', 87, 'alternative'),
#  ('2015-08-09', 88, 'alternative'),
#  ('2015-08-16', 87, 'alternative'),
#  ('2015-08-23', 86, 'alternative'),
#  ('2015-08-30', 84, 'alternative'),
#  ('2015-09-06', 76, 'alternative'),
#  ('2015-09-13', 84, 'alternative'),
#  ('2015-09-20', 83, 'alternative'),
#  ('2015-09-27', 78, 'alternative'),
#  ('2015-10-04', 80, 'alternative'),
#  ('2015-10-11', 79, 'alternative'),
#  ('2015-10-18', 86, 'alternative'),
#  ('2015-10-25', 83, 'alternative'),
#  ('2015-11-01', 81, 'alternative'),
#  ('2015-11-08', 74, 'alternative'),
#  ('2015-11-15', 79, 'alternative'),
#  ('2015-11-22', 76, 'alternative'),
#  ('2015-11-29', 82, 'alternative'),
#  ('2015-12-06', 86, 'alternative'),
#  ('2015-12-13', 76, 'alternative'),
#  ('2015-12-20', 84, 'alternative'),
#  ('2015-12-27', 79, 'alternative'),
#  ('2016-01-03', 78, 'alternative'),
#  ('2016-01-10', 72, 'alternative'),
#  ('2016-01-17', 76, 'alternative'),
#  ('2016-01-24', 77, 'alternative'),
#  ('2016-01-31', 79, 'alternative'),
#  ('2016-02-07', 75, 'alternative'),
#  ('2016-02-14', 81, 'alternative'),
#  ('2016-02-21', 77, 'alternative'),
#  ('2016-02-28', 75, 'alternative'),
#  ('2016-03-06', 81, 'alternative'),
#  ('2016-03-13', 78, 'alternative'),
#  ('2016-03-20', 76, 'alternative'),
#  ('2016-03-27', 88, 'alternative'),
#  ('2016-04-03', 80, 'alternative'),
#  ('2016-04-10', 74, 'alternative'),
#  ('2016-04-17', 78, 'alternative'),
#  ('2016-04-24', 78, 'alternative'),
#  ('2016-05-01', 82, 'alternative'),
#  ('2016-05-08', 69, 'alternative'),
#  ('2016-05-15', 80, 'alternative'),
#  ('2016-05-22', 74, 'alternative'),
#  ('2016-05-29', 65, 'alternative'),
#  ('2016-06-05', 69, 'alternative'),
#  ('2016-06-12', 75, 'alternative'),
#  ('2016-06-19', 78, 'alternative'),
#  ('2016-06-26', 79, 'alternative'),
#  ('2016-07-03', 70, 'alternative'),
#  ('2016-07-10', 66, 'alternative'),
#  ('2016-07-17', 84, 'alternative'),
#  ('2016-07-24', 74, 'alternative'),
#  ('2016-07-31', 71, 'alternative'),
#  ('2016-08-07', 65, 'alternative'),
#  ('2016-08-14', 68, 'alternative'),
#  ('2016-08-21', 70, 'alternative'),
#  ('2016-08-28', 78, 'alternative'),
#  ('2016-09-04', 72, 'alternative'),
#  ('2016-09-11', 73, 'alternative'),
#  ('2016-09-18', 69, 'alternative'),
#  ('2016-09-25', 66, 'alternative'),
#  ('2016-10-02', 64, 'alternative'),
#  ('2016-10-09', 67, 'alternative'),
#  ('2016-10-16', 70, 'alternative'),
#  ('2016-10-23', 73, 'alternative'),
#  ('2016-10-30', 65, 'alternative'),
#  ('2016-11-06', 64, 'alternative'),
#  ('2016-11-13', 73, 'alternative'),
#  ('2016-11-20', 70, 'alternative'),
#  ('2016-11-27', 76, 'alternative'),
#  ('2016-12-04', 70, 'alternative'),
#  ('2016-12-11', 72, 'alternative'),
#  ('2016-12-18', 78, 'alternative'),
#  ('2016-12-25', 75, 'alternative'),
#  ('2017-01-01', 70, 'alternative'),
#  ('2017-01-08', 77, 'alternative'),
#  ('2017-01-15', 68, 'alternative'),
#  ('2017-01-22', 82, 'alternative'),
#  ('2017-01-29', 75, 'alternative'),
#  ('2017-02-05', 76, 'alternative'),
#  ('2017-02-12', 71, 'alternative'),
#  ('2017-02-19', 75, 'alternative'),
#  ('2017-02-26', 70, 'alternative'),
#  ('2017-03-05', 71, 'alternative'),
#  ('2017-03-12', 72, 'alternative'),
#  ('2017-03-19', 78, 'alternative'),
#  ('2017-03-26', 72, 'alternative'),
#  ('2017-04-02', 74, 'alternative'),
#  ('2017-04-09', 72, 'alternative'),
#  ('2017-04-16', 72, 'alternative'),
#  ('2017-04-23', 76, 'alternative'),
#  ('2017-04-30', 70, 'alternative'),
#  ('2017-05-07', 69, 'alternative'),
#  ('2017-05-14', 69, 'alternative'),
#  ('2017-05-21', 70, 'alternative'),
#  ('2017-05-28', 70, 'alternative'),
#  ('2017-06-04', 61, 'alternative'),
#  ('2017-06-11', 66, 'alternative'),
#  ('2017-06-18', 73, 'alternative'),
#  ('2017-06-25', 70, 'alternative'),
#  ('2017-07-02', 66, 'alternative'),
#  ('2017-07-09', 74, 'alternative'),
#  ('2017-07-16', 77, 'alternative'),
#  ('2017-07-23', 74, 'alternative'),
#  ('2017-07-30', 69, 'alternative'),
#  ('2017-08-06', 74, 'alternative'),
#  ('2017-08-13', 72, 'alternative'),
#  ('2017-08-20', 67, 'alternative'),
#  ('2017-08-27', 63, 'alternative'),
#  ('2017-09-03', 71, 'alternative'),
#  ('2017-09-10', 67, 'alternative'),
#  ('2017-09-17', 68, 'alternative'),
#  ('2017-09-24', 65, 'alternative'),
#  ('2017-10-01', 66, 'alternative'),
#  ('2017-10-08', 64, 'alternative'),
#  ('2017-10-15', 70, 'alternative'),
#  ('2017-10-22', 66, 'alternative'),
#  ('2017-10-29', 63, 'alternative'),
#  ('2017-11-05', 67, 'alternative'),
#  ('2017-11-12', 71, 'alternative'),
#  ('2017-11-19', 73, 'alternative'),
#  ('2017-11-26', 72, 'alternative'),
#  ('2017-12-03', 70, 'alternative'),
#  ('2017-12-10', 66, 'alternative'),
#  ('2017-12-17', 65, 'alternative'),
#  ('2017-12-24', 67, 'alternative'),
#  ('2017-12-31', 67, 'alternative'),
#  ('2018-01-07', 65, 'alternative'),
#  ('2018-01-14', 70, 'alternative'),
#  ('2018-01-21', 66, 'alternative'),
#  ('2018-01-28', 76, 'alternative'),
#  ('2018-02-04', 69, 'alternative'),
#  ('2018-02-11', 73, 'alternative'),
#  ('2018-02-18', 67, 'alternative'),
#  ('2018-02-25', 64, 'alternative'),
#  ('2018-03-04', 78, 'alternative'),
#  ('2018-03-11', 71, 'alternative'),
#  ('2018-03-18', 70, 'alternative'),
#  ('2018-03-25', 69, 'alternative'),
#  ('2018-04-01', 66, 'alternative'),
#  ('2018-04-08', 71, 'alternative'),
#  ('2018-04-15', 70, 'alternative'),
#  ('2018-04-22', 69, 'alternative'),
#  ('2018-04-29', 66, 'alternative'),
#  ('2018-05-06', 72, 'alternative'),
#  ('2018-05-13', 63, 'alternative'),
#  ('2018-05-20', 62, 'alternative'),
#  ('2018-05-27', 61, 'alternative'),
#  ('2018-06-03', 64, 'alternative'),
#  ('2018-06-10', 60, 'alternative'),
#  ('2018-06-17', 60, 'alternative'),
#  ('2018-06-24', 63, 'alternative'),
#  ('2018-07-01', 54, 'alternative'),
#  ('2018-07-08', 67, 'alternative'),
#  ('2018-07-15', 59, 'alternative'),
#  ('2018-07-22', 63, 'alternative'),
#  ('2018-07-29', 66, 'alternative'),
#  ('2018-08-05', 60, 'alternative'),
#  ('2018-08-12', 67, 'alternative'),
#  ('2018-08-19', 68, 'alternative'),
#  ('2018-08-26', 61, 'alternative'),
#  ('2018-09-02', 63, 'alternative'),
#  ('2018-09-09', 61, 'alternative'),
#  ('2018-09-16', 58, 'alternative'),
#  ('2018-09-23', 60, 'alternative'),
#  ('2018-09-30', 58, 'alternative'),
#  ('2018-10-07', 61, 'alternative'),
#  ('2018-10-14', 65, 'alternative'),
#  ('2018-10-21', 61, 'alternative'),
#  ('2018-10-28', 60, 'alternative'),
#  ('2018-11-04', 58, 'alternative'),
#  ('2018-11-11', 60, 'alternative'),
#  ('2018-11-18', 59, 'alternative'),
#  ('2018-11-25', 60, 'alternative'),
#  ('2018-12-02', 63, 'alternative'),
#  ('2018-12-09', 58, 'alternative'),
#  ('2018-12-16', 67, 'alternative'),
#  ('2018-12-23', 69, 'alternative'),
#  ('2018-12-30', 67, 'alternative'),
#  ('2019-01-06', 64, 'alternative'),
#  ('2019-01-13', 60, 'alternative'),
#  ('2019-01-20', 59, 'alternative'),
#  ('2019-01-27', 59, 'alternative'),
#  ('2019-02-03', 63, 'alternative'),
#  ('2019-02-10', 65, 'alternative'),
#  ('2019-02-17', 64, 'alternative'),
#  ('2019-02-24', 61, 'alternative'),
#  ('2019-03-03', 64, 'alternative'),
#  ('2019-03-10', 62, 'alternative'),
#  ('2019-03-17', 61, 'alternative'),
#  ('2019-03-24', 61, 'alternative'),
#  ('2019-03-31', 56, 'alternative'),
#  ('2019-04-07', 57, 'alternative'),
#  ('2019-04-14', 54, 'alternative'),
#  ('2019-04-21', 64, 'alternative'),
#  ('2019-04-28', 61, 'alternative'),
#  ('2019-05-05', 58, 'alternative'),
#  ('2019-05-12', 54, 'alternative'),
#  ('2019-05-19', 59, 'alternative'),
#  ('2019-05-26', 62, 'alternative'),
#  ('2019-06-02', 57, 'alternative'),
#  ('2019-06-09', 56, 'alternative'),
#  ('2019-06-16', 58, 'alternative'),
#  ('2019-06-23', 55, 'alternative'),
#  ('2019-06-30', 58, 'alternative'),
#  ('2019-07-07', 60, 'alternative'),
#  ('2019-07-14', 65, 'alternative'),
#  ('2019-07-21', 65, 'alternative'),
#  ('2019-07-28', 58, 'alternative'),
#  ('2019-08-04', 58, 'alternative'),
#  ('2019-08-11', 61, 'alternative'),
#  ('2019-08-18', 56, 'alternative'),
#  ('2019-08-25', 57, 'alternative'),
#  ('2019-09-01', 60, 'alternative'),
#  ('2019-09-08', 67, 'alternative'),
#  ('2019-09-15', 54, 'alternative'),
#  ('2019-09-22', 59, 'alternative'),
#  ('2019-09-29', 60, 'alternative'),
#  ('2019-10-06', 58, 'alternative'),
#  ('2019-10-13', 59, 'alternative'),
#  ('2019-10-20', 54, 'alternative'),
#  ('2019-10-27', 52, 'alternative'),
#  ('2019-11-03', 59, 'alternative'),
#  ('2019-11-10', 57, 'alternative'),
#  ('2019-11-17', 57, 'alternative'),
#  ('2019-11-24', 59, 'alternative'),
#  ('2019-12-01', 58, 'alternative'),
#  ('2019-12-08', 54, 'alternative'),
#  ('2019-12-15', 56, 'alternative'),
#  ('2019-12-22', 59, 'alternative'),
#  ('2019-12-29', 65, 'alternative'),
#  ('2020-01-05', 65, 'alternative'),
#  ('2020-01-12', 63, 'alternative'),
#  ('2020-01-19', 60, 'alternative'),
#  ('2020-01-26', 61, 'alternative'),
#  ('2020-02-02', 63, 'alternative'),
#  ('2020-02-09', 60, 'alternative'),
#  ('2020-02-16', 58, 'alternative'),
#  ('2020-02-23', 61, 'alternative'),
#  ('2020-03-01', 56, 'alternative'),
#  ('2020-03-08', 54, 'alternative'),
#  ('2020-03-15', 52, 'alternative'),
#  ('2020-03-22', 66, 'alternative'),
#  ('2020-03-29', 71, 'alternative'),
#  ('2020-04-05', 71, 'alternative'),
#  ('2020-04-12', 66, 'alternative'),
#  ('2020-04-19', 73, 'alternative'),
#  ('2020-04-26', 72, 'alternative'),
#  ('2015-05-03', 70, 'folk'),
#  ('2015-05-10', 71, 'folk'),
#  ('2015-05-17', 76, 'folk'),
#  ('2015-05-24', 69, 'folk'),
#  ('2015-05-31', 84, 'folk'),
#  ('2015-06-07', 80, 'folk'),
#  ('2015-06-14', 79, 'folk'),
#  ('2015-06-21', 84, 'folk'),
#  ('2015-06-28', 77, 'folk'),
#  ('2015-07-05', 83, 'folk'),
#  ('2015-07-12', 80, 'folk'),
#  ('2015-07-19', 100, 'folk'),
#  ('2015-07-26', 95, 'folk'),
#  ('2015-08-02', 94, 'folk'),
#  ('2015-08-09', 85, 'folk'),
#  ('2015-08-16', 72, 'folk'),
#  ('2015-08-23', 73, 'folk'),
#  ('2015-08-30', 75, 'folk'),
#  ('2015-09-06', 76, 'folk'),
#  ('2015-09-13', 73, 'folk'),
#  ('2015-09-20', 70, 'folk'),
#  ('2015-09-27', 74, 'folk'),
#  ('2015-10-04', 68, 'folk'),
#  ('2015-10-11', 74, 'folk'),
#  ('2015-10-18', 75, 'folk'),
#  ('2015-10-25', 67, 'folk'),
#  ('2015-11-01', 75, 'folk'),
#  ('2015-11-08', 68, 'folk'),
#  ('2015-11-15', 62, 'folk'),
#  ('2015-11-22', 65, 'folk'),
#  ('2015-11-29', 74, 'folk'),
#  ('2015-12-06', 72, 'folk'),
#  ('2015-12-13', 69, 'folk'),
#  ('2015-12-20', 71, 'folk'),
#  ('2015-12-27', 75, 'folk'),
#  ('2016-01-03', 69, 'folk'),
#  ('2016-01-10', 79, 'folk'),
#  ('2016-01-17', 71, 'folk'),
#  ('2016-01-24', 71, 'folk'),
#  ('2016-01-31', 73, 'folk'),
#  ('2016-02-07', 76, 'folk'),
#  ('2016-02-14', 67, 'folk'),
#  ('2016-02-21', 74, 'folk'),
#  ('2016-02-28', 68, 'folk'),
#  ('2016-03-06', 68, 'folk'),
#  ('2016-03-13', 64, 'folk'),
#  ('2016-03-20', 79, 'folk'),
#  ('2016-03-27', 69, 'folk'),
#  ('2016-04-03', 71, 'folk'),
#  ('2016-04-10', 71, 'folk'),
#  ('2016-04-17', 69, 'folk'),
#  ('2016-04-24', 79, 'folk'),
#  ('2016-05-01', 77, 'folk'),
#  ('2016-05-08', 70, 'folk'),
#  ('2016-05-15', 71, 'folk'),
#  ('2016-05-22', 73, 'folk'),
#  ('2016-05-29', 75, 'folk'),
#  ('2016-06-05', 73, 'folk'),
#  ('2016-06-12', 69, 'folk'),
#  ('2016-06-19', 81, 'folk'),
#  ('2016-06-26', 76, 'folk'),
#  ('2016-07-03', 79, 'folk'),
#  ('2016-07-10', 78, 'folk'),
#  ('2016-07-17', 95, 'folk'),
#  ('2016-07-24', 84, 'folk'),
#  ('2016-07-31', 86, 'folk'),
#  ('2016-08-07', 81, 'folk'),
#  ('2016-08-14', 69, 'folk'),
#  ('2016-08-21', 82, 'folk'),
#  ('2016-08-28', 85, 'folk'),
#  ('2016-09-04', 74, 'folk'),
#  ('2016-09-11', 78, 'folk'),
#  ('2016-09-18', 74, 'folk'),
#  ('2016-09-25', 64, 'folk'),
#  ('2016-10-02', 78, 'folk'),
#  ('2016-10-09', 75, 'folk'),
#  ('2016-10-16', 74, 'folk'),
#  ('2016-10-23', 74, 'folk'),
#  ('2016-10-30', 73, 'folk'),
#  ('2016-11-06', 73, 'folk'),
#  ('2016-11-13', 68, 'folk'),
#  ('2016-11-20', 69, 'folk'),
#  ('2016-11-27', 74, 'folk'),
#  ('2016-12-04', 73, 'folk'),
#  ('2016-12-11', 66, 'folk'),
#  ('2016-12-18', 67, 'folk'),
#  ('2016-12-25', 76, 'folk'),
#  ('2017-01-01', 76, 'folk'),
#  ('2017-01-08', 74, 'folk'),
#  ('2017-01-15', 72, 'folk'),
#  ('2017-01-22', 76, 'folk'),
#  ('2017-01-29', 78, 'folk'),
#  ('2017-02-05', 77, 'folk'),
#  ('2017-02-12', 72, 'folk'),
#  ('2017-02-19', 77, 'folk'),
#  ('2017-02-26', 69, 'folk'),
#  ('2017-03-05', 78, 'folk'),
#  ('2017-03-12', 81, 'folk'),
#  ('2017-03-19', 75, 'folk'),
#  ('2017-03-26', 70, 'folk'),
#  ('2017-04-02', 80, 'folk'),
#  ('2017-04-09', 75, 'folk'),
#  ('2017-04-16', 71, 'folk'),
#  ('2017-04-23', 69, 'folk'),
#  ('2017-04-30', 75, 'folk'),
#  ('2017-05-07', 69, 'folk'),
#  ('2017-05-14', 68, 'folk'),
#  ('2017-05-21', 62, 'folk'),
#  ('2017-05-28', 69, 'folk'),
#  ('2017-06-04', 72, 'folk'),
#  ('2017-06-11', 71, 'folk'),
#  ('2017-06-18', 76, 'folk'),
#  ('2017-06-25', 73, 'folk'),
#  ('2017-07-02', 78, 'folk'),
#  ('2017-07-09', 73, 'folk'),
#  ('2017-07-16', 82, 'folk'),
#  ('2017-07-23', 88, 'folk'),
#  ('2017-07-30', 93, 'folk'),
#  ('2017-08-06', 97, 'folk'),
#  ('2017-08-13', 94, 'folk'),
#  ('2017-08-20', 82, 'folk'),
#  ('2017-08-27', 75, 'folk'),
#  ('2017-09-03', 65, 'folk'),
#  ('2017-09-10', 61, 'folk'),
#  ('2017-09-17', 64, 'folk'),
#  ('2017-09-24', 67, 'folk'),
#  ('2017-10-01', 63, 'folk'),
#  ('2017-10-08', 73, 'folk'),
#  ('2017-10-15', 62, 'folk'),
#  ('2017-10-22', 60, 'folk'),
#  ('2017-10-29', 67, 'folk'),
#  ('2017-11-05', 67, 'folk'),
#  ('2017-11-12', 63, 'folk'),
#  ('2017-11-19', 64, 'folk'),
#  ('2017-11-26', 62, 'folk'),
#  ('2017-12-03', 66, 'folk'),
#  ('2017-12-10', 66, 'folk'),
#  ('2017-12-17', 61, 'folk'),
#  ('2017-12-24', 70, 'folk'),
#  ('2017-12-31', 69, 'folk'),
#  ('2018-01-07', 67, 'folk'),
#  ('2018-01-14', 67, 'folk'),
#  ('2018-01-21', 66, 'folk'),
#  ('2018-01-28', 67, 'folk'),
#  ('2018-02-04', 62, 'folk'),
#  ('2018-02-11', 66, 'folk'),
#  ('2018-02-18', 64, 'folk'),
#  ('2018-02-25', 67, 'folk'),
#  ('2018-03-04', 63, 'folk'),
#  ('2018-03-11', 68, 'folk'),
#  ('2018-03-18', 62, 'folk'),
#  ('2018-03-25', 65, 'folk'),
#  ('2018-04-01', 66, 'folk'),
#  ('2018-04-08', 57, 'folk'),
#  ('2018-04-15', 58, 'folk'),
#  ('2018-04-22', 64, 'folk'),
#  ('2018-04-29', 59, 'folk'),
#  ('2018-05-06', 66, 'folk'),
#  ('2018-05-13', 59, 'folk'),
#  ('2018-05-20', 60, 'folk'),
#  ('2018-05-27', 60, 'folk'),
#  ('2018-06-03', 65, 'folk'),
#  ('2018-06-10', 62, 'folk'),
#  ('2018-06-17', 62, 'folk'),
#  ('2018-06-24', 60, 'folk'),
#  ('2018-07-01', 83, 'folk'),
#  ('2018-07-08', 70, 'folk'),
#  ('2018-07-15', 72, 'folk'),
#  ('2018-07-22', 81, 'folk'),
#  ('2018-07-29', 86, 'folk'),
#  ('2018-08-05', 76, 'folk'),
#  ('2018-08-12', 73, 'folk'),
#  ('2018-08-19', 76, 'folk'),
#  ('2018-08-26', 67, 'folk'),
#  ('2018-09-02', 66, 'folk'),
#  ('2018-09-09', 65, 'folk'),
#  ('2018-09-16', 64, 'folk'),
#  ('2018-09-23', 61, 'folk'),
#  ('2018-09-30', 61, 'folk'),
#  ('2018-10-07', 66, 'folk'),
#  ('2018-10-14', 63, 'folk'),
#  ('2018-10-21', 59, 'folk'),
#  ('2018-10-28', 66, 'folk'),
#  ('2018-11-04', 64, 'folk'),
#  ('2018-11-11', 67, 'folk'),
#  ('2018-11-18', 59, 'folk'),
#  ('2018-11-25', 67, 'folk'),
#  ('2018-12-02', 60, 'folk'),
#  ('2018-12-09', 60, 'folk'),
#  ('2018-12-16', 57, 'folk'),
#  ('2018-12-23', 66, 'folk'),
#  ('2018-12-30', 60, 'folk'),
#  ('2019-01-06', 57, 'folk'),
#  ('2019-01-13', 63, 'folk'),
#  ('2019-01-20', 66, 'folk'),
#  ('2019-01-27', 60, 'folk'),
#  ('2019-02-03', 65, 'folk'),
#  ('2019-02-10', 61, 'folk'),
#  ('2019-02-17', 58, 'folk'),
#  ('2019-02-24', 57, 'folk'),
#  ('2019-03-03', 66, 'folk'),
#  ('2019-03-10', 62, 'folk'),
#  ('2019-03-17', 60, 'folk'),
#  ('2019-03-24', 59, 'folk'),
#  ('2019-03-31', 57, 'folk'),
#  ('2019-04-07', 60, 'folk'),
#  ('2019-04-14', 55, 'folk'),
#  ('2019-04-21', 58, 'folk'),
#  ('2019-04-28', 56, 'folk'),
#  ('2019-05-05', 63, 'folk'),
#  ('2019-05-12', 56, 'folk'),
#  ('2019-05-19', 58, 'folk'),
#  ('2019-05-26', 64, 'folk'),
#  ('2019-06-02', 57, 'folk'),
#  ('2019-06-09', 61, 'folk'),
#  ('2019-06-16', 59, 'folk'),
#  ('2019-06-23', 58, 'folk'),
#  ('2019-06-30', 62, 'folk'),
#  ('2019-07-07', 66, 'folk'),
#  ('2019-07-14', 66, 'folk'),
#  ('2019-07-21', 71, 'folk'),
#  ('2019-07-28', 68, 'folk'),
#  ('2019-08-04', 71, 'folk'),
#  ('2019-08-11', 65, 'folk'),
#  ('2019-08-18', 61, 'folk'),
#  ('2019-08-25', 56, 'folk'),
#  ('2019-09-01', 63, 'folk'),
#  ('2019-09-08', 55, 'folk'),
#  ('2019-09-15', 54, 'folk'),
#  ('2019-09-22', 53, 'folk'),
#  ('2019-09-29', 52, 'folk'),
#  ('2019-10-06', 59, 'folk'),
#  ('2019-10-13', 56, 'folk'),
#  ('2019-10-20', 55, 'folk'),
#  ('2019-10-27', 59, 'folk'),
#  ('2019-11-03', 57, 'folk'),
#  ('2019-11-10', 53, 'folk'),
#  ('2019-11-17', 56, 'folk'),
#  ('2019-11-24', 53, 'folk'),
#  ('2019-12-01', 53, 'folk'),
#  ('2019-12-08', 49, 'folk'),
#  ('2019-12-15', 48, 'folk'),
#  ('2019-12-22', 57, 'folk'),
#  ('2019-12-29', 54, 'folk'),
#  ('2020-01-05', 54, 'folk'),
#  ('2020-01-12', 60, 'folk'),
#  ('2020-01-19', 57, 'folk'),
#  ('2020-01-26', 57, 'folk'),
#  ('2020-02-02', 58, 'folk'),
#  ('2020-02-09', 50, 'folk'),
#  ('2020-02-16', 54, 'folk'),
#  ('2020-02-23', 54, 'folk'),
#  ('2020-03-01', 56, 'folk'),
#  ('2020-03-08', 52, 'folk'),
#  ('2020-03-15', 43, 'folk'),
#  ('2020-03-22', 46, 'folk'),
#  ('2020-03-29', 54, 'folk'),
#  ('2020-04-05', 49, 'folk'),
#  ('2020-04-12', 52, 'folk'),
#  ('2020-04-19', 52, 'folk'),
#  ('2020-04-26', 57, 'folk'),
#  ('2015-05-03', 75, 'jazz'),
#  ('2015-05-10', 76, 'jazz'),
#  ('2015-05-17', 78, 'jazz'),
#  ('2015-05-24', 77, 'jazz'),
#  ('2015-05-31', 76, 'jazz'),
#  ('2015-06-07', 75, 'jazz'),
#  ('2015-06-14', 77, 'jazz'),
#  ('2015-06-21', 85, 'jazz'),
#  ('2015-06-28', 87, 'jazz'),
#  ('2015-07-05', 92, 'jazz'),
#  ('2015-07-12', 93, 'jazz'),
#  ('2015-07-19', 84, 'jazz'),
#  ('2015-07-26', 84, 'jazz'),
#  ('2015-08-02', 78, 'jazz'),
#  ('2015-08-09', 75, 'jazz'),
#  ('2015-08-16', 74, 'jazz'),
#  ('2015-08-23', 71, 'jazz'),
#  ('2015-08-30', 69, 'jazz'),
#  ('2015-09-06', 69, 'jazz'),
#  ('2015-09-13', 69, 'jazz'),
#  ('2015-09-20', 68, 'jazz'),
#  ('2015-09-27', 66, 'jazz'),
#  ('2015-10-04', 67, 'jazz'),
#  ('2015-10-11', 69, 'jazz'),
#  ('2015-10-18', 71, 'jazz'),
#  ('2015-10-25', 68, 'jazz'),
#  ('2015-11-01', 70, 'jazz'),
#  ('2015-11-08', 70, 'jazz'),
#  ('2015-11-15', 68, 'jazz'),
#  ('2015-11-22', 67, 'jazz'),
#  ('2015-11-29', 70, 'jazz'),
#  ('2015-12-06', 69, 'jazz'),
#  ('2015-12-13', 69, 'jazz'),
#  ('2015-12-20', 70, 'jazz'),
#  ('2015-12-27', 69, 'jazz'),
#  ('2016-01-03', 69, 'jazz'),
#  ('2016-01-10', 68, 'jazz'),
#  ('2016-01-17', 79, 'jazz'),
#  ('2016-01-24', 72, 'jazz'),
#  ('2016-01-31', 73, 'jazz'),
#  ('2016-02-07', 68, 'jazz'),
#  ('2016-02-14', 71, 'jazz'),
#  ('2016-02-21', 72, 'jazz'),
#  ('2016-02-28', 70, 'jazz'),
#  ('2016-03-06', 72, 'jazz'),
#  ('2016-03-13', 69, 'jazz'),
#  ('2016-03-20', 70, 'jazz'),
#  ('2016-03-27', 74, 'jazz'),
#  ('2016-04-03', 73, 'jazz'),
#  ('2016-04-10', 74, 'jazz'),
#  ('2016-04-17', 81, 'jazz'),
#  ('2016-04-24', 86, 'jazz'),
#  ('2016-05-01', 74, 'jazz'),
#  ('2016-05-08', 67, 'jazz'),
#  ('2016-05-15', 69, 'jazz'),
#  ('2016-05-22', 69, 'jazz'),
#  ('2016-05-29', 72, 'jazz'),
#  ('2016-06-05', 70, 'jazz'),
#  ('2016-06-12', 70, 'jazz'),
#  ('2016-06-19', 71, 'jazz'),
#  ('2016-06-26', 77, 'jazz'),
#  ('2016-07-03', 82, 'jazz'),
#  ('2016-07-10', 76, 'jazz'),
#  ('2016-07-17', 69, 'jazz'),
#  ('2016-07-24', 65, 'jazz'),
#  ('2016-07-31', 62, 'jazz'),
#  ('2016-08-07', 64, 'jazz'),
#  ('2016-08-14', 59, 'jazz'),
#  ('2016-08-21', 62, 'jazz'),
#  ('2016-08-28', 62, 'jazz'),
#  ('2016-09-04', 65, 'jazz'),
#  ('2016-09-11', 62, 'jazz'),
#  ('2016-09-18', 62, 'jazz'),
#  ('2016-09-25', 60, 'jazz'),
#  ('2016-10-02', 63, 'jazz'),
#  ('2016-10-09', 62, 'jazz'),
#  ('2016-10-16', 58, 'jazz'),
#  ('2016-10-23', 63, 'jazz'),
#  ('2016-10-30', 60, 'jazz'),
#  ('2016-11-06', 62, 'jazz'),
#  ('2016-11-13', 67, 'jazz'),
#  ('2016-11-20', 63, 'jazz'),
#  ('2016-11-27', 65, 'jazz'),
#  ('2016-12-04', 65, 'jazz'),
#  ('2016-12-11', 63, 'jazz'),
#  ('2016-12-18', 63, 'jazz'),
#  ('2016-12-25', 61, 'jazz'),
#  ('2017-01-01', 64, 'jazz'),
#  ('2017-01-08', 67, 'jazz'),
#  ('2017-01-15', 68, 'jazz'),
#  ('2017-01-22', 72, 'jazz'),
#  ('2017-01-29', 72, 'jazz'),
#  ('2017-02-05', 72, 'jazz'),
#  ('2017-02-12', 72, 'jazz'),
#  ('2017-02-19', 74, 'jazz'),
#  ('2017-02-26', 75, 'jazz'),
#  ('2017-03-05', 71, 'jazz'),
#  ('2017-03-12', 70, 'jazz'),
#  ('2017-03-19', 71, 'jazz'),
#  ('2017-03-26', 72, 'jazz'),
#  ('2017-04-02', 71, 'jazz'),
#  ('2017-04-09', 67, 'jazz'),
#  ('2017-04-16', 75, 'jazz'),
#  ('2017-04-23', 87, 'jazz'),
#  ('2017-04-30', 96, 'jazz'),
#  ('2017-05-07', 76, 'jazz'),
#  ('2017-05-14', 67, 'jazz'),
#  ('2017-05-21', 69, 'jazz'),
#  ('2017-05-28', 70, 'jazz'),
#  ('2017-06-04', 69, 'jazz'),
#  ('2017-06-11', 69, 'jazz'),
#  ('2017-06-18', 74, 'jazz'),
#  ('2017-06-25', 87, 'jazz'),
#  ('2017-07-02', 86, 'jazz'),
#  ('2017-07-09', 79, 'jazz'),
#  ('2017-07-16', 70, 'jazz'),
#  ('2017-07-23', 68, 'jazz'),
#  ('2017-07-30', 72, 'jazz'),
#  ('2017-08-06', 68, 'jazz'),
#  ('2017-08-13', 60, 'jazz'),
#  ('2017-08-20', 62, 'jazz'),
#  ('2017-08-27', 62, 'jazz'),
#  ('2017-09-03', 62, 'jazz'),
#  ('2017-09-10', 61, 'jazz'),
#  ('2017-09-17', 61, 'jazz'),
#  ('2017-09-24', 61, 'jazz'),
#  ('2017-10-01', 62, 'jazz'),
#  ('2017-10-08', 63, 'jazz'),
#  ('2017-10-15', 63, 'jazz'),
#  ('2017-10-22', 63, 'jazz'),
#  ('2017-10-29', 63, 'jazz'),
#  ('2017-11-05', 64, 'jazz'),
#  ('2017-11-12', 69, 'jazz'),
#  ('2017-11-19', 62, 'jazz'),
#  ('2017-11-26', 66, 'jazz'),
#  ('2017-12-03', 66, 'jazz'),
#  ('2017-12-10', 63, 'jazz'),
#  ('2017-12-17', 63, 'jazz'),
#  ('2017-12-24', 62, 'jazz'),
#  ('2017-12-31', 65, 'jazz'),
#  ('2018-01-07', 66, 'jazz'),
#  ('2018-01-14', 68, 'jazz'),
#  ('2018-01-21', 73, 'jazz'),
#  ('2018-01-28', 70, 'jazz'),
#  ('2018-02-04', 68, 'jazz'),
#  ('2018-02-11', 68, 'jazz'),
#  ('2018-02-18', 68, 'jazz'),
#  ('2018-02-25', 65, 'jazz'),
#  ('2018-03-04', 66, 'jazz'),
#  ('2018-03-11', 70, 'jazz'),
#  ('2018-03-18', 71, 'jazz'),
#  ('2018-03-25', 68, 'jazz'),
#  ('2018-04-01', 66, 'jazz'),
#  ('2018-04-08', 73, 'jazz'),
#  ('2018-04-15', 75, 'jazz'),
#  ('2018-04-22', 100, 'jazz'),
#  ('2018-04-29', 92, 'jazz'),
#  ('2018-05-06', 73, 'jazz'),
#  ('2018-05-13', 61, 'jazz'),
#  ('2018-05-20', 62, 'jazz'),
#  ('2018-05-27', 63, 'jazz'),
#  ('2018-06-03', 66, 'jazz'),
#  ('2018-06-10', 63, 'jazz'),
#  ('2018-06-17', 64, 'jazz'),
#  ('2018-06-24', 70, 'jazz'),
#  ('2018-07-01', 71, 'jazz'),
#  ('2018-07-08', 69, 'jazz'),
#  ('2018-07-15', 73, 'jazz'),
#  ('2018-07-22', 63, 'jazz'),
#  ('2018-07-29', 62, 'jazz'),
#  ('2018-08-05', 62, 'jazz'),
#  ('2018-08-12', 61, 'jazz'),
#  ('2018-08-19', 62, 'jazz'),
#  ('2018-08-26', 62, 'jazz'),
#  ('2018-09-02', 59, 'jazz'),
#  ('2018-09-09', 58, 'jazz'),
#  ('2018-09-16', 59, 'jazz'),
#  ('2018-09-23', 58, 'jazz'),
#  ('2018-09-30', 59, 'jazz'),
#  ('2018-10-07', 59, 'jazz'),
#  ('2018-10-14', 66, 'jazz'),
#  ('2018-10-21', 60, 'jazz'),
#  ('2018-10-28', 62, 'jazz'),
#  ('2018-11-04', 64, 'jazz'),
#  ('2018-11-11', 62, 'jazz'),
#  ('2018-11-18', 61, 'jazz'),
#  ('2018-11-25', 61, 'jazz'),
#  ('2018-12-02', 65, 'jazz'),
#  ('2018-12-09', 67, 'jazz'),
#  ('2018-12-16', 64, 'jazz'),
#  ('2018-12-23', 64, 'jazz'),
#  ('2018-12-30', 67, 'jazz'),
#  ('2019-01-06', 69, 'jazz'),
#  ('2019-01-13', 80, 'jazz'),
#  ('2019-01-20', 71, 'jazz'),
#  ('2019-01-27', 70, 'jazz'),
#  ('2019-02-03', 70, 'jazz'),
#  ('2019-02-10', 70, 'jazz'),
#  ('2019-02-17', 68, 'jazz'),
#  ('2019-02-24', 69, 'jazz'),
#  ('2019-03-03', 72, 'jazz'),
#  ('2019-03-10', 66, 'jazz'),
#  ('2019-03-17', 69, 'jazz'),
#  ('2019-03-24', 70, 'jazz'),
#  ('2019-03-31', 66, 'jazz'),
#  ('2019-04-07', 65, 'jazz'),
#  ('2019-04-14', 65, 'jazz'),
#  ('2019-04-21', 79, 'jazz'),
#  ('2019-04-28', 75, 'jazz'),
#  ('2019-05-05', 62, 'jazz'),
#  ('2019-05-12', 63, 'jazz'),
#  ('2019-05-19', 66, 'jazz'),
#  ('2019-05-26', 61, 'jazz'),
#  ('2019-06-02', 64, 'jazz'),
#  ('2019-06-09', 65, 'jazz'),
#  ('2019-06-16', 68, 'jazz'),
#  ('2019-06-23', 71, 'jazz'),
#  ('2019-06-30', 72, 'jazz'),
#  ('2019-07-07', 74, 'jazz'),
#  ('2019-07-14', 71, 'jazz'),
#  ('2019-07-21', 67, 'jazz'),
#  ('2019-07-28', 65, 'jazz'),
#  ('2019-08-04', 63, 'jazz'),
#  ('2019-08-11', 67, 'jazz'),
#  ('2019-08-18', 65, 'jazz'),
#  ('2019-08-25', 62, 'jazz'),
#  ('2019-09-01', 59, 'jazz'),
#  ('2019-09-08', 58, 'jazz'),
#  ('2019-09-15', 58, 'jazz'),
#  ('2019-09-22', 59, 'jazz'),
#  ('2019-09-29', 57, 'jazz'),
#  ('2019-10-06', 58, 'jazz'),
#  ('2019-10-13', 61, 'jazz'),
#  ('2019-10-20', 63, 'jazz'),
#  ('2019-10-27', 63, 'jazz'),
#  ('2019-11-03', 73, 'jazz'),
#  ('2019-11-10', 72, 'jazz'),
#  ('2019-11-17', 68, 'jazz'),
#  ('2019-11-24', 60, 'jazz'),
#  ('2019-12-01', 59, 'jazz'),
#  ('2019-12-08', 66, 'jazz'),
#  ('2019-12-15', 61, 'jazz'),
#  ('2019-12-22', 72, 'jazz'),
#  ('2019-12-29', 67, 'jazz'),
#  ('2020-01-05', 67, 'jazz'),
#  ('2020-01-12', 71, 'jazz'),
#  ('2020-01-19', 70, 'jazz'),
#  ('2020-01-26', 66, 'jazz'),
#  ('2020-02-02', 62, 'jazz'),
#  ('2020-02-09', 71, 'jazz'),
#  ('2020-02-16', 65, 'jazz'),
#  ('2020-02-23', 67, 'jazz'),
#  ('2020-03-01', 63, 'jazz'),
#  ('2020-03-08', 66, 'jazz'),
#  ('2020-03-15', 49, 'jazz'),
#  ('2020-03-22', 53, 'jazz'),
#  ('2020-03-29', 54, 'jazz'),
#  ('2020-04-05', 55, 'jazz'),
#  ('2020-04-12', 53, 'jazz'),
#  ('2020-04-19', 54, 'jazz'),
#  ('2020-04-26', 55, 'jazz'),
#  ('2015-05-03', 67, 'pop'),
#  ('2015-05-10', 67, 'pop'),
#  ('2015-05-17', 66, 'pop'),
#  ('2015-05-24', 63, 'pop'),
#  ('2015-05-31', 66, 'pop'),
#  ('2015-06-07', 64, 'pop'),
#  ('2015-06-14', 63, 'pop'),
#  ('2015-06-21', 65, 'pop'),
#  ('2015-06-28', 66, 'pop'),
#  ('2015-07-05', 65, 'pop'),
#  ('2015-07-12', 66, 'pop'),
#  ('2015-07-19', 67, 'pop'),
#  ('2015-07-26', 67, 'pop'),
#  ('2015-08-02', 68, 'pop'),
#  ('2015-08-09', 67, 'pop'),
#  ('2015-08-16', 67, 'pop'),
#  ('2015-08-23', 65, 'pop'),
#  ('2015-08-30', 65, 'pop'),
#  ('2015-09-06', 67, 'pop'),
#  ('2015-09-13', 66, 'pop'),
#  ('2015-09-20', 66, 'pop'),
#  ('2015-09-27', 64, 'pop'),
#  ('2015-10-04', 64, 'pop'),
#  ('2015-10-11', 66, 'pop'),
#  ('2015-10-18', 65, 'pop'),
#  ('2015-10-25', 64, 'pop'),
#  ('2015-11-01', 64, 'pop'),
#  ('2015-11-08', 63, 'pop'),
#  ('2015-11-15', 65, 'pop'),
#  ('2015-11-22', 64, 'pop'),
#  ('2015-11-29', 66, 'pop'),
#  ('2015-12-06', 66, 'pop'),
#  ('2015-12-13', 66, 'pop'),
#  ('2015-12-20', 67, 'pop'),
#  ('2015-12-27', 69, 'pop'),
#  ('2016-01-03', 63, 'pop'),
#  ('2016-01-10', 74, 'pop'),
#  ('2016-01-17', 69, 'pop'),
#  ('2016-01-24', 67, 'pop'),
#  ('2016-01-31', 65, 'pop'),
#  ('2016-02-07', 64, 'pop'),
#  ('2016-02-14', 65, 'pop'),
#  ('2016-02-21', 64, 'pop'),
#  ('2016-02-28', 64, 'pop'),
#  ('2016-03-06', 66, 'pop'),
#  ('2016-03-13', 65, 'pop'),
#  ('2016-03-20', 65, 'pop'),
#  ('2016-03-27', 65, 'pop'),
#  ('2016-04-03', 91, 'pop'),
#  ('2016-04-10', 75, 'pop'),
#  ('2016-04-17', 75, 'pop'),
#  ('2016-04-24', 74, 'pop'),
#  ('2016-05-01', 71, 'pop'),
#  ('2016-05-08', 70, 'pop'),
#  ('2016-05-15', 71, 'pop'),
#  ('2016-05-22', 70, 'pop'),
#  ('2016-05-29', 68, 'pop'),
#  ('2016-06-05', 66, 'pop'),
#  ('2016-06-12', 63, 'pop'),
#  ('2016-06-19', 68, 'pop'),
#  ('2016-06-26', 65, 'pop'),
#  ('2016-07-03', 63, 'pop'),
#  ('2016-07-10', 62, 'pop'),
#  ('2016-07-17', 62, 'pop'),
#  ('2016-07-24', 64, 'pop'),
#  ('2016-07-31', 62, 'pop'),
#  ('2016-08-07', 63, 'pop'),
#  ('2016-08-14', 65, 'pop'),
#  ('2016-08-21', 67, 'pop'),
#  ('2016-08-28', 64, 'pop'),
#  ('2016-09-04', 64, 'pop'),
#  ('2016-09-11', 62, 'pop'),
#  ('2016-09-18', 61, 'pop'),
#  ('2016-09-25', 62, 'pop'),
#  ('2016-10-02', 62, 'pop'),
#  ('2016-10-09', 62, 'pop'),
#  ('2016-10-16', 62, 'pop'),
#  ('2016-10-23', 62, 'pop'),
#  ('2016-10-30', 62, 'pop'),
#  ('2016-11-06', 59, 'pop'),
#  ('2016-11-13', 63, 'pop'),
#  ('2016-11-20', 62, 'pop'),
#  ('2016-11-27', 60, 'pop'),
#  ('2016-12-04', 60, 'pop'),
#  ('2016-12-11', 61, 'pop'),
#  ('2016-12-18', 63, 'pop'),
#  ('2016-12-25', 65, 'pop'),
#  ('2017-01-01', 61, 'pop'),
#  ('2017-01-08', 69, 'pop'),
#  ('2017-01-15', 62, 'pop'),
#  ('2017-01-22', 61, 'pop'),
#  ('2017-01-29', 60, 'pop'),
#  ('2017-02-05', 61, 'pop'),
#  ('2017-02-12', 61, 'pop'),
#  ('2017-02-19', 60, 'pop'),
#  ('2017-02-26', 63, 'pop'),
#  ('2017-03-05', 61, 'pop'),
#  ('2017-03-12', 60, 'pop'),
#  ('2017-03-19', 60, 'pop'),
#  ('2017-03-26', 60, 'pop'),
#  ('2017-04-02', 60, 'pop'),
#  ('2017-04-09', 61, 'pop'),
#  ('2017-04-16', 63, 'pop'),
#  ('2017-04-23', 59, 'pop'),
#  ('2017-04-30', 60, 'pop'),
#  ('2017-05-07', 59, 'pop'),
#  ('2017-05-14', 58, 'pop'),
#  ('2017-05-21', 58, 'pop'),
#  ('2017-05-28', 59, 'pop'),
#  ('2017-06-04', 60, 'pop'),
#  ('2017-06-11', 58, 'pop'),
#  ('2017-06-18', 58, 'pop'),
#  ('2017-06-25', 58, 'pop'),
#  ('2017-07-02', 58, 'pop'),
#  ('2017-07-09', 60, 'pop'),
#  ('2017-07-16', 59, 'pop'),
#  ('2017-07-23', 59, 'pop'),
#  ('2017-07-30', 60, 'pop'),
#  ('2017-08-06', 59, 'pop'),
#  ('2017-08-13', 58, 'pop'),
#  ('2017-08-20', 57, 'pop'),
#  ('2017-08-27', 54, 'pop'),
#  ('2017-09-03', 54, 'pop'),
#  ('2017-09-10', 53, 'pop'),
#  ('2017-09-17', 55, 'pop'),
#  ('2017-09-24', 55, 'pop'),
#  ('2017-10-01', 54, 'pop'),
#  ('2017-10-08', 54, 'pop'),
#  ('2017-10-15', 54, 'pop'),
#  ('2017-10-22', 53, 'pop'),
#  ('2017-10-29', 53, 'pop'),
#  ('2017-11-05', 54, 'pop'),
#  ('2017-11-12', 55, 'pop'),
#  ('2017-11-19', 55, 'pop'),
#  ('2017-11-26', 53, 'pop'),
#  ('2017-12-03', 55, 'pop'),
#  ('2017-12-10', 55, 'pop'),
#  ('2017-12-17', 61, 'pop'),
#  ('2017-12-24', 59, 'pop'),
#  ('2017-12-31', 58, 'pop'),
#  ('2018-01-07', 58, 'pop'),
#  ('2018-01-14', 58, 'pop'),
#  ('2018-01-21', 56, 'pop'),
#  ('2018-01-28', 57, 'pop'),
#  ('2018-02-04', 55, 'pop'),
#  ('2018-02-11', 56, 'pop'),
#  ('2018-02-18', 55, 'pop'),
#  ('2018-02-25', 55, 'pop'),
#  ('2018-03-04', 55, 'pop'),
#  ('2018-03-11', 54, 'pop'),
#  ('2018-03-18', 52, 'pop'),
#  ('2018-03-25', 55, 'pop'),
#  ('2018-04-01', 53, 'pop'),
#  ('2018-04-08', 51, 'pop'),
#  ('2018-04-15', 55, 'pop'),
#  ('2018-04-22', 53, 'pop'),
#  ('2018-04-29', 53, 'pop'),
#  ('2018-05-06', 52, 'pop'),
#  ('2018-05-13', 51, 'pop'),
#  ('2018-05-20', 50, 'pop'),
#  ('2018-05-27', 51, 'pop'),
#  ('2018-06-03', 51, 'pop'),
#  ('2018-06-10', 49, 'pop'),
#  ('2018-06-17', 45, 'pop'),
#  ('2018-06-24', 48, 'pop'),
#  ('2018-07-01', 48, 'pop'),
#  ('2018-07-08', 49, 'pop'),
#  ('2018-07-15', 50, 'pop'),
#  ('2018-07-22', 51, 'pop'),
#  ('2018-07-29', 49, 'pop'),
#  ('2018-08-05', 50, 'pop'),
#  ('2018-08-12', 50, 'pop'),
#  ('2018-08-19', 50, 'pop'),
#  ('2018-08-26', 50, 'pop'),
#  ('2018-09-02', 50, 'pop'),
#  ('2018-09-09', 48, 'pop'),
#  ('2018-09-16', 48, 'pop'),
#  ('2018-09-23', 48, 'pop'),
#  ('2018-09-30', 49, 'pop'),
#  ('2018-10-07', 47, 'pop'),
#  ('2018-10-14', 49, 'pop'),
#  ('2018-10-21', 48, 'pop'),
#  ('2018-10-28', 49, 'pop'),
#  ('2018-11-04', 50, 'pop'),
#  ('2018-11-11', 49, 'pop'),
#  ('2018-11-18', 50, 'pop'),
#  ('2018-11-25', 49, 'pop'),
#  ('2018-12-02', 52, 'pop'),
#  ('2018-12-09', 51, 'pop'),
#  ('2018-12-16', 52, 'pop'),
#  ('2018-12-23', 53, 'pop'),
#  ('2018-12-30', 52, 'pop'),
#  ('2019-01-06', 49, 'pop'),
#  ('2019-01-13', 48, 'pop'),
#  ('2019-01-20', 47, 'pop'),
#  ('2019-01-27', 48, 'pop'),
#  ('2019-02-03', 48, 'pop'),
#  ('2019-02-10', 48, 'pop'),
#  ('2019-02-17', 47, 'pop'),
#  ('2019-02-24', 46, 'pop'),
#  ('2019-03-03', 46, 'pop'),
#  ('2019-03-10', 46, 'pop'),
#  ('2019-03-17', 47, 'pop'),
#  ('2019-03-24', 49, 'pop'),
#  ('2019-03-31', 47, 'pop'),
#  ('2019-04-07', 47, 'pop'),
#  ('2019-04-14', 47, 'pop'),
#  ('2019-04-21', 48, 'pop'),
#  ('2019-04-28', 49, 'pop'),
#  ('2019-05-05', 45, 'pop'),
#  ('2019-05-12', 46, 'pop'),
#  ('2019-05-19', 44, 'pop'),
#  ('2019-05-26', 47, 'pop'),
#  ('2019-06-02', 44, 'pop'),
#  ('2019-06-09', 46, 'pop'),
#  ('2019-06-16', 48, 'pop'),
#  ('2019-06-23', 47, 'pop'),
#  ...]

# %% [markdown]
# To see change in interest overtime, I did a Period-Over-Period Analysis with the window function LAG(). This function calculated the change in interest per year for each music genre. I also grouped and ordered the data by year and genre.

# %%
# %%sql
# SELECT
#     LEFT(`date`,4) AS google_year, genre,
#     SUM(interest) AS yearly_interest,
#     LAG(sum(interest),1) OVER(PARTITION BY genre ORDER BY LEFT(`date`, 4)) AS previous_year_interest,
#     (SUM(interest)
#     - LAG(sum(interest),1) OVER(PARTITION BY genre ORDER BY LEFT(`date`, 4)))
#     / LAG(sum(interest),1) OVER(PARTITION BY genre ORDER BY LEFT(`date`, 4))
#     * 100 AS interest_growth
# FROM google_interest_by_genre
# WHERE `date` BETWEEN "2015-05-03" AND "2020-04-26"
# GROUP BY google_year, genre
# ORDER BY genre, google_year;
# Out:
#  * mysql://admin:***@lmu-sql.c8zmikzpsjej.us-east-2.rds.amazonaws.com/sql_project
# 54 rows affected.
# [('2015', 'alternative', Decimal('2912'), None, None),
#  ('2016', 'alternative', Decimal('3837'), Decimal('2912'), Decimal('31.7651')),
#  ('2017', 'alternative', Decimal('3723'), Decimal('3837'), Decimal('-2.9711')),
#  ('2018', 'alternative', Decimal('3358'), Decimal('3723'), Decimal('-9.8039')),
#  ('2019', 'alternative', Decimal('3079'), Decimal('3358'), Decimal('-8.3085')),
#  ('2020', 'alternative', Decimal('1072'), Decimal('3079'), Decimal('-65.1835')),
#  ('2015', 'folk', Decimal('2655'), None, None),
#  ('2016', 'folk', Decimal('3852'), Decimal('2655'), Decimal('45.0847')),
#  ('2017', 'folk', Decimal('3837'), Decimal('3852'), Decimal('-0.3894')),
#  ('2018', 'folk', Decimal('3397'), Decimal('3837'), Decimal('-11.4673')),
#  ('2019', 'folk', Decimal('3068'), Decimal('3397'), Decimal('-9.6850')),
#  ('2020', 'folk', Decimal('905'), Decimal('3068'), Decimal('-70.5020')),
#  ('2015', 'jazz', Decimal('2595'), None, None),
#  ('2016', 'jazz', Decimal('3545'), Decimal('2595'), Decimal('36.6089')),
#  ('2017', 'jazz', Decimal('3663'), Decimal('3545'), Decimal('3.3286')),
#  ('2018', 'jazz', Decimal('3449'), Decimal('3663'), Decimal('-5.8422')),
#  ('2019', 'jazz', Decimal('3454'), Decimal('3449'), Decimal('0.1450')),
#  ('2020', 'jazz', Decimal('1041'), Decimal('3454'), Decimal('-69.8610')),
#  ('2015', 'pop', Decimal('2296'), None, None),
#  ('2016', 'pop', Decimal('3407'), Decimal('2296'), Decimal('48.3885')),
#  ('2017', 'pop', Decimal('3084'), Decimal('3407'), Decimal('-9.4805')),
#  ('2018', 'pop', Decimal('2669'), Decimal('3084'), Decimal('-13.4565')),
#  ('2019', 'pop', Decimal('2676'), Decimal('2669'), Decimal('0.2623')),
#  ('2020', 'pop', Decimal('791'), Decimal('2676'), Decimal('-70.4410')),
#  ('2015', 'rap', Decimal('2773'), None, None),
#  ('2016', 'rap', Decimal('4081'), Decimal('2773'), Decimal('47.1691')),
#  ('2017', 'rap', Decimal('3913'), Decimal('4081'), Decimal('-4.1166')),
#  ('2018', 'rap', Decimal('3180'), Decimal('3913'), Decimal('-18.7324')),
#  ('2019', 'rap', Decimal('2757'), Decimal('3180'), Decimal('-13.3019')),
#  ('2020', 'rap', Decimal('841'), Decimal('2757'), Decimal('-69.4958')),
#  ('2015', 'reggae', Decimal('3082'), None, None),
#  ('2016', 'reggae', Decimal('4055'), Decimal('3082'), Decimal('31.5704')),
#  ('2017', 'reggae', Decimal('3532'), Decimal('4055'), Decimal('-12.8977')),
#  ('2018', 'reggae', Decimal('3099'), Decimal('3532'), Decimal('-12.2593')),
#  ('2019', 'reggae', Decimal('3004'), Decimal('3099'), Decimal('-3.0655')),
#  ('2020', 'reggae', Decimal('773'), Decimal('3004'), Decimal('-74.2676')),
#  ('2015', 'rnb', Decimal('2998'), None, None),
#  ('2016', 'rnb', Decimal('4129'), Decimal('2998'), Decimal('37.7252')),
#  ('2017', 'rnb', Decimal('4112'), Decimal('4129'), Decimal('-0.4117')),
#  ('2018', 'rnb', Decimal('3716'), Decimal('4112'), Decimal('-9.6304')),
#  ('2019', 'rnb', Decimal('3559'), Decimal('3716'), Decimal('-4.2250')),
#  ('2020', 'rnb', Decimal('1180'), Decimal('3559'), Decimal('-66.8446')),
#  ('2015', 'rock', Decimal('2824'), None, None),
#  ('2016', 'rock', Decimal('3756'), Decimal('2824'), Decimal('33.0028')),
#  ('2017', 'rock', Decimal('3625'), Decimal('3756'), Decimal('-3.4878')),
#  ('2018', 'rock', Decimal('3139'), Decimal('3625'), Decimal('-13.4069')),
#  ('2019', 'rock', Decimal('3023'), Decimal('3139'), Decimal('-3.6954')),
#  ('2020', 'rock', Decimal('889'), Decimal('3023'), Decimal('-70.5921')),
#  ('2015', 'soul', Decimal('846'), None, None),
#  ('2016', 'soul', Decimal('1437'), Decimal('846'), Decimal('69.8582')),
#  ('2017', 'soul', Decimal('1011'), Decimal('1437'), Decimal('-29.6451')),
#  ('2018', 'soul', Decimal('865'), Decimal('1011'), Decimal('-14.4411')),
#  ('2019', 'soul', Decimal('798'), Decimal('865'), Decimal('-7.7457')),
#  ('2020', 'soul', Decimal('270'), Decimal('798'), Decimal('-66.1654'))]

# %% [markdown]
# From the data, we see that interest in Alternative Music, Folk Music, Instrumental, Pop, Rap, Reggae, Rnb, Rock and Soul was decreasing progressively over 5 years
#
# Jazz Music saw an increase from 2016 to 2017, a decrease from 2017-2018 and then held steady.
#
# Looking further into Jazz, was there a particular month that caused this spike? If so, can we then dig deeper to know if there was an event or album released that month in Jazz?
#
# I looked into the day to day data for Jazz and saw that on April 22, 2018, where interest was ranked 100, there was a Utah Jazz Basketball game where they beat Oklahoma City thunder 115-102. Although I had limited my API to the category of music, this would make sense why there was such a surge in interest for the word "jazz".
#
# While this complicated function seems insightful and paints an interesting story on the data, the results serve as a reminder of how difficult pulling accurate, targeted data can be. In the future, I would love to perform this query on a better data set, perhaps one provided by the company itself.

# %% [markdown]
# # Exploratory Query 2

# %% [markdown]
# I wanted to look into individual countries and see what music genre was the most popular in each of the countries.
#
# In order to do this, I used a CASE statement to categorize and label what genre was most popular in comparison to another in a country.

# %%
# %%sql
# SELECT geoName, Rock, Pop, Instrumental, Rap, RnB,
#     CASE
#         WHEN Rock>Pop AND Rock>Instrumental AND Rock>Rap AND Rock>RnB THEN "Rock"
#         WHEN Pop>Rock AND Pop>Instrumental AND Pop>Rap AND Pop>RnB THEN "Pop"
#         WHEN Instrumental>Rock AND Instrumental>Pop AND Instrumental>Rap AND Instrumental>RnB THEN "Instrumental"
#         WHEN Rap>Rock AND Rap>Pop AND Rap>Instrumental AND Rap>RnB THEN "Rap"
#         WHEN RnB>Rock AND RnB>Pop AND RnB>Instrumental AND RnB>Rap THEN "RnB"
#         ELSE "none"
#     END AS most_popular_genre_per_country
# FROM popularity_by_country;
# Out:
#  * mysql://admin:***@lmu-sql.c8zmikzpsjej.us-east-2.rds.amazonaws.com/sql_project
# 250 rows affected.
# [('Afghanistan', 54, 27, 4, 15, 0, 'Rock'),
#  ('Albania', 47, 32, 5, 16, 0, 'Rock'),
#  ('Algeria', 21, 20, 7, 50, 2, 'Rap'),
#  ('American Samoa', 54, 16, 10, 20, 0, 'Rock'),
#  ('Andorra', 57, 23, 3, 17, 0, 'Rock'),
#  ('Angola', 9, 7, 49, 35, 0, 'Instrumental'),
#  ('Anguilla', 52, 24, 10, 14, 0, 'Rock'),
#  ('Antarctica', 0, 0, 0, 0, 0, 'none'),
#  ('Antigua & Barbuda', 51, 25, 9, 15, 0, 'Rock'),
#  ('Argentina', 50, 26, 4, 20, 0, 'Rock'),
#  ('Armenia', 34, 36, 10, 20, 0, 'Pop'),
#  ('Aruba', 57, 26, 6, 11, 0, 'Rock'),
#  ('Australia', 57, 29, 2, 9, 3, 'Rock'),
#  ('Austria', 68, 21, 2, 9, 0, 'Rock'),
#  ('Azerbaijan', 27, 37, 11, 25, 0, 'Pop'),
#  ('Bahamas', 54, 20, 7, 18, 1, 'Rock'),
#  ('Bahrain', 49, 29, 6, 16, 0, 'Rock'),
#  ('Bangladesh', 24, 15, 7, 54, 0, 'Rap'),
#  ('Barbados', 61, 20, 7, 12, 0, 'Rock'),
#  ('Belarus', 52, 27, 8, 12, 1, 'Rock'),
#  ('Belgium', 51, 33, 2, 14, 0, 'Rock'),
#  ('Belize', 52, 23, 9, 16, 0, 'Rock'),
#  ('Benin', 17, 14, 30, 36, 3, 'Rap'),
#  ('Bermuda', 62, 22, 5, 11, 0, 'Rock'),
#  ('Bhutan', 27, 21, 4, 48, 0, 'Rap'),
#  ('Bolivia', 29, 18, 7, 46, 0, 'Rap'),
#  ('Bosnia & Herzegovina', 47, 39, 4, 10, 0, 'Rock'),
#  ('Botswana', 40, 19, 16, 16, 9, 'Rock'),
#  ('Bouvet Island', 0, 0, 0, 0, 0, 'none'),
#  ('Brazil', 50, 27, 4, 19, 0, 'Rock'),
#  ('British Indian Ocean Territory', 100, 0, 0, 0, 0, 'Rock'),
#  ('British Virgin Islands', 69, 16, 8, 7, 0, 'Rock'),
#  ('Brunei', 49, 35, 5, 11, 0, 'Rock'),
#  ('Bulgaria', 53, 29, 5, 13, 0, 'Rock'),
#  ('Burkina Faso', 39, 10, 11, 38, 2, 'Rock'),
#  ('Burundi', 26, 19, 40, 15, 0, 'Instrumental'),
#  ('Cambodia', 44, 36, 3, 17, 0, 'Rock'),
#  ('Cameroon', 21, 17, 21, 38, 3, 'Rap'),
#  ('Canada', 62, 26, 2, 10, 0, 'Rock'),
#  ('Cape Verde', 29, 19, 21, 29, 2, 'none'),
#  ('Caribbean Netherlands', 53, 33, 14, 0, 0, 'Rock'),
#  ('Cayman Islands', 64, 21, 5, 10, 0, 'Rock'),
#  ('Central African Republic', 44, 0, 20, 36, 0, 'Rock'),
#  ('Chad', 20, 15, 18, 47, 0, 'Rap'),
#  ('Chile', 44, 31, 5, 20, 0, 'Rock'),
#  ('China', 43, 38, 5, 13, 1, 'Rock'),
#  ('Christmas Island', 0, 0, 0, 0, 0, 'none'),
#  ('Cocos (Keeling) Islands', 0, 0, 0, 0, 0, 'none'),
#  ('Colombia', 37, 23, 15, 25, 0, 'Rock'),
#  ('Comoros', 0, 0, 26, 74, 0, 'Rap'),
#  ('Congo - Brazzaville', 13, 8, 32, 45, 2, 'Rap'),
#  ('Congo - Kinshasa', 17, 12, 27, 41, 3, 'Rap'),
#  ('Cook Islands', 61, 39, 0, 0, 0, 'Rock'),
#  ('Costa Rica', 42, 25, 16, 17, 0, 'Rock'),
#  ('Croatia', 55, 31, 3, 10, 1, 'Rock'),
#  ('Cuba', 36, 27, 14, 23, 0, 'Rock'),
#  ('Curaçao', 51, 28, 9, 12, 0, 'Rock'),
#  ('Cyprus', 49, 37, 3, 9, 2, 'Rock'),
#  ('Czechia', 72, 18, 2, 8, 0, 'Rock'),
#  ('Côte d’Ivoire', 13, 16, 17, 52, 2, 'Rap'),
#  ('Denmark', 57, 26, 2, 15, 0, 'Rock'),
#  ('Djibouti', 46, 18, 3, 33, 0, 'Rock'),
#  ('Dominica', 43, 28, 12, 17, 0, 'Rock'),
#  ('Dominican Republic', 36, 21, 14, 29, 0, 'Rock'),
#  ('Ecuador', 29, 15, 12, 44, 0, 'Rap'),
#  ('Egypt', 50, 31, 4, 15, 0, 'Rock'),
#  ('El Salvador', 29, 24, 12, 35, 0, 'Rap'),
#  ('Equatorial Guinea', 11, 10, 32, 47, 0, 'Rap'),
#  ('Eritrea', 100, 0, 0, 0, 0, 'Rock'),
#  ('Estonia', 60, 27, 3, 10, 0, 'Rock'),
#  ('Eswatini', 32, 17, 26, 17, 8, 'Rock'),
#  ('Ethiopia', 40, 20, 16, 24, 0, 'Rock'),
#  ('Falkland Islands (Islas Malvinas)', 72, 28, 0, 0, 0, 'Rock'),
#  ('Faroe Islands', 60, 25, 2, 13, 0, 'Rock'),
#  ('Fiji', 53, 24, 10, 13, 0, 'Rock'),
#  ('Finland', 49, 44, 1, 6, 0, 'Rock'),
#  ('France', 39, 33, 2, 25, 1, 'Rock'),
#  ('French Guiana', 30, 27, 9, 31, 3, 'Rap'),
#  ('French Polynesia', 46, 30, 5, 18, 1, 'Rock'),
#  ('French Southern Territories', 0, 0, 0, 0, 0, 'none'),
#  ('Gabon', 15, 12, 22, 48, 3, 'Rap'),
#  ('Gambia', 26, 24, 26, 20, 4, 'none'),
#  ('Georgia', 50, 31, 5, 14, 0, 'Rock'),
#  ('Germany', 64, 21, 3, 12, 0, 'Rock'),
#  ('Ghana', 27, 19, 38, 14, 2, 'Instrumental'),
#  ('Gibraltar', 79, 16, 1, 4, 0, 'Rock'),
#  ('Greece', 56, 31, 2, 9, 2, 'Rock'),
#  ('Greenland', 57, 25, 0, 18, 0, 'Rock'),
#  ('Grenada', 49, 26, 6, 17, 2, 'Rock'),
#  ('Guadeloupe', 33, 27, 10, 28, 2, 'Rock'),
#  ('Guam', 56, 28, 3, 13, 0, 'Rock'),
#  ('Guatemala', 30, 18, 18, 34, 0, 'Rap'),
#  ('Guernsey', 69, 23, 1, 7, 0, 'Rock'),
#  ('Guinea', 10, 8, 23, 56, 3, 'Rap'),
#  ('Guinea-Bissau', 14, 11, 37, 38, 0, 'Rap'),
#  ('Guyana', 45, 24, 15, 15, 1, 'Rock'),
#  ('Haiti', 14, 6, 32, 47, 1, 'Rap'),
#  ('Heard & McDonald Islands', 0, 0, 0, 0, 0, 'none'),
#  ('Honduras', 37, 18, 14, 31, 0, 'Rock'),
#  ('Hong Kong', 47, 41, 3, 9, 0, 'Rock'),
#  ('Hungary', 62, 25, 2, 11, 0, 'Rock'),
#  ('Iceland', 62, 24, 2, 12, 0, 'Rock'),
#  ('India', 31, 23, 17, 29, 0, 'Rock'),
#  ('Indonesia', 37, 50, 6, 6, 1, 'Pop'),
#  ('Iran', 43, 29, 7, 21, 0, 'Rock'),
#  ('Iraq', 35, 28, 3, 34, 0, 'Rock'),
#  ('Ireland', 61, 29, 2, 8, 0, 'Rock'),
#  ('Isle of Man', 59, 33, 1, 7, 0, 'Rock'),
#  ('Israel', 48, 38, 3, 11, 0, 'Rock'),
#  ('Italy', 51, 30, 2, 17, 0, 'Rock'),
#  ('Jamaica', 47, 24, 14, 12, 3, 'Rock'),
#  ('Japan', 53, 42, 1, 4, 0, 'Rock'),
#  ('Jersey', 66, 26, 1, 7, 0, 'Rock'),
#  ('Jordan', 49, 33, 4, 14, 0, 'Rock'),
#  ('Kazakhstan', 38, 36, 11, 14, 1, 'Rock'),
#  ('Kenya', 42, 21, 16, 12, 9, 'Rock'),
#  ('Kiribati', 0, 0, 0, 0, 0, 'none'),
#  ('Kosovo', 39, 32, 10, 19, 0, 'Rock'),
#  ('Kuwait', 49, 30, 5, 16, 0, 'Rock'),
#  ('Kyrgyzstan', 29, 36, 16, 18, 1, 'Pop'),
#  ('Laos', 43, 30, 7, 20, 0, 'Rock'),
#  ('Latvia', 58, 26, 4, 12, 0, 'Rock'),
#  ('Lebanon', 49, 27, 4, 19, 1, 'Rock'),
#  ('Lesotho', 35, 16, 23, 16, 10, 'Rock'),
#  ('Liberia', 28, 11, 43, 14, 4, 'Instrumental'),
#  ('Libya', 40, 24, 7, 29, 0, 'Rock'),
#  ('Liechtenstein', 64, 25, 2, 9, 0, 'Rock'),
#  ('Lithuania', 51, 34, 4, 11, 0, 'Rock'),
#  ('Luxembourg', 63, 23, 2, 12, 0, 'Rock'),
#  ('Macao', 58, 30, 2, 10, 0, 'Rock'),
#  ('Madagascar', 31, 14, 20, 25, 10, 'Rock'),
#  ('Malawi', 22, 12, 52, 11, 3, 'Instrumental'),
#  ('Malaysia', 58, 29, 5, 8, 0, 'Rock'),
#  ('Maldives', 56, 25, 4, 15, 0, 'Rock'),
#  ('Mali', 8, 8, 11, 73, 0, 'Rap'),
#  ('Malta', 62, 27, 3, 8, 0, 'Rock'),
#  ('Marshall Islands', 100, 0, 0, 0, 0, 'Rock'),
#  ('Martinique', 32, 27, 9, 30, 2, 'Rock'),
#  ('Mauritania', 7, 8, 18, 67, 0, 'Rap'),
#  ('Mauritius', 48, 28, 10, 13, 1, 'Rock'),
#  ('Mayotte', 20, 19, 13, 48, 0, 'Rap'),
#  ('Mexico', 36, 29, 12, 23, 0, 'Rock'),
#  ('Micronesia', 100, 0, 0, 0, 0, 'Rock'),
#  ('Moldova', 39, 27, 8, 26, 0, 'Rock'),
#  ('Monaco', 54, 29, 2, 15, 0, 'Rock'),
#  ('Mongolia', 43, 30, 10, 17, 0, 'Rock'),
#  ('Montenegro', 40, 48, 4, 8, 0, 'Pop'),
#  ('Montserrat', 0, 0, 0, 0, 0, 'none'),
#  ('Morocco', 27, 23, 6, 43, 1, 'Rap'),
#  ('Mozambique', 17, 7, 47, 27, 2, 'Instrumental'),
#  ('Myanmar (Burma)', 47, 37, 4, 12, 0, 'Rock'),
#  ('Namibia', 44, 20, 16, 14, 6, 'Rock'),
#  ('Nauru', 0, 0, 0, 0, 0, 'none'),
#  ('Nepal', 29, 45, 4, 22, 0, 'Pop'),
#  ('Netherlands', 44, 41, 3, 12, 0, 'Rock'),
#  ('New Caledonia', 46, 27, 3, 23, 1, 'Rock'),
#  ('New Zealand', 60, 27, 3, 10, 0, 'Rock'),
#  ('Nicaragua', 36, 18, 17, 29, 0, 'Rock'),
#  ('Niger', 20, 14, 14, 52, 0, 'Rap'),
#  ('Nigeria', 27, 16, 43, 13, 1, 'Instrumental'),
#  ('Niue', 0, 0, 0, 0, 0, 'none'),
#  ('Norfolk Island', 0, 0, 0, 0, 0, 'none'),
#  ('North Korea', 0, 0, 0, 0, 0, 'none'),
#  ('North Macedonia', 44, 38, 4, 14, 0, 'Rock'),
#  ('Northern Mariana Islands', 52, 28, 7, 13, 0, 'Rock'),
#  ('Norway', 60, 23, 3, 14, 0, 'Rock'),
#  ('Oman', 49, 28, 8, 15, 0, 'Rock'),
#  ('Pakistan', 29, 21, 10, 40, 0, 'Rap'),
#  ('Palau', 100, 0, 0, 0, 0, 'Rock'),
#  ('Palestine', 52, 35, 3, 10, 0, 'Rock'),
#  ('Panama', 48, 20, 17, 15, 0, 'Rock'),
#  ('Papua New Guinea', 50, 23, 11, 13, 3, 'Rock'),
#  ('Paraguay', 45, 23, 6, 26, 0, 'Rock'),
#  ('Peru', 32, 20, 7, 41, 0, 'Rap'),
#  ('Philippines', 51, 28, 8, 12, 1, 'Rock'),
#  ('Pitcairn Islands', 0, 0, 0, 0, 0, 'none'),
#  ('Poland', 52, 22, 3, 23, 0, 'Rock'),
#  ('Portugal', 59, 27, 4, 10, 0, 'Rock'),
#  ('Puerto Rico', 44, 39, 9, 8, 0, 'Rock'),
#  ('Qatar', 44, 35, 5, 15, 1, 'Rock'),
#  ('Romania', 47, 40, 3, 10, 0, 'Rock'),
#  ('Russia', 47, 32, 7, 13, 1, 'Rock'),
#  ('Rwanda', 48, 18, 16, 15, 3, 'Rock'),
#  ('Réunion', 28, 28, 6, 37, 1, 'Rap'),
#  ('Samoa', 62, 14, 11, 13, 0, 'Rock'),
#  ('San Marino', 62, 23, 3, 12, 0, 'Rock'),
#  ('Saudi Arabia', 47, 35, 5, 13, 0, 'Rock'),
#  ('Senegal', 13, 20, 18, 46, 3, 'Rap'),
#  ('Serbia', 45, 44, 4, 7, 0, 'Rock'),
#  ('Seychelles', 52, 19, 17, 12, 0, 'Rock'),
#  ('Sierra Leone', 20, 14, 49, 14, 3, 'Instrumental'),
#  ('Singapore', 49, 39, 4, 8, 0, 'Rock'),
#  ('Sint Maarten', 57, 22, 6, 15, 0, 'Rock'),
#  ('Slovakia', 70, 19, 2, 9, 0, 'Rock'),
#  ('Slovenia', 22, 76, 0, 2, 0, 'Pop'),
#  ('Solomon Islands', 54, 15, 16, 11, 4, 'Rock'),
#  ('Somalia', 49, 18, 10, 23, 0, 'Rock'),
#  ('South Africa', 48, 20, 13, 14, 5, 'Rock'),
#  ('South Georgia & South Sandwich Islands', 0, 0, 0, 0, 0, 'none'),
#  ('South Korea', 43, 42, 6, 9, 0, 'Rock'),
#  ('South Sudan', 33, 16, 35, 16, 0, 'Instrumental'),
#  ('Spain', 53, 27, 4, 16, 0, 'Rock'),
#  ('Sri Lanka', 28, 9, 8, 55, 0, 'Rap'),
#  ('St. Barthélemy', 44, 20, 9, 27, 0, 'Rock'),
#  ('St. Helena', 54, 28, 4, 14, 0, 'Rock'),
#  ('St. Kitts & Nevis', 67, 17, 6, 10, 0, 'Rock'),
#  ('St. Lucia', 45, 30, 11, 14, 0, 'Rock'),
#  ('St. Martin', 63, 17, 5, 15, 0, 'Rock'),
#  ('St. Pierre & Miquelon', 74, 26, 0, 0, 0, 'Rock'),
#  ('St. Vincent & Grenadines', 44, 26, 12, 16, 2, 'Rock'),
#  ('Sudan', 40, 23, 16, 20, 1, 'Rock'),
#  ('Suriname', 43, 34, 11, 12, 0, 'Rock'),
#  ('Svalbard & Jan Mayen', 0, 0, 0, 0, 0, 'none'),
#  ('Sweden', 62, 25, 2, 10, 1, 'Rock'),
#  ('Switzerland', 55, 27, 2, 15, 1, 'Rock'),
#  ('Syria', 46, 31, 4, 19, 0, 'Rock'),
#  ('São Tomé & Príncipe', 36, 25, 14, 25, 0, 'Rock'),
#  ('Taiwan', 47, 39, 2, 12, 0, 'Rock'),
#  ('Tajikistan', 11, 10, 9, 70, 0, 'Rap'),
#  ('Tanzania', 33, 12, 33, 9, 13, 'none'),
#  ('Thailand', 44, 42, 2, 12, 0, 'Rock'),
#  ('Timor-Leste', 38, 43, 11, 8, 0, 'Pop'),
#  ('Togo', 17, 17, 28, 36, 2, 'Rap'),
#  ('Tokelau', 0, 0, 0, 0, 0, 'none'),
#  ('Tonga', 71, 29, 0, 0, 0, 'Rock'),
#  ('Trinidad & Tobago', 49, 27, 10, 13, 1, 'Rock'),
#  ('Tunisia', 25, 21, 4, 49, 1, 'Rap'),
#  ('Turkey', 21, 52, 0, 27, 0, 'Pop'),
#  ('Turkmenistan', 15, 34, 12, 39, 0, 'Rap'),
#  ('Turks & Caicos Islands', 59, 21, 5, 15, 0, 'Rock'),
#  ('Tuvalu', 0, 0, 0, 0, 0, 'none'),
#  ('U.S. Outlying Islands', 0, 0, 0, 0, 0, 'none'),
#  ('U.S. Virgin Islands', 64, 19, 6, 11, 0, 'Rock'),
#  ('Uganda', 41, 18, 24, 12, 5, 'Rock'),
#  ('Ukraine', 53, 25, 8, 13, 1, 'Rock'),
#  ('United Arab Emirates', 50, 31, 5, 13, 1, 'Rock'),
#  ('United Kingdom', 56, 34, 2, 8, 0, 'Rock'),
#  ('United States', 66, 22, 2, 10, 0, 'Rock'),
#  ('Uruguay', 44, 23, 5, 28, 0, 'Rock'),
#  ('Uzbekistan', 26, 27, 16, 30, 1, 'Rap'),
#  ('Vanuatu', 50, 23, 15, 12, 0, 'Rock'),
#  ('Vatican City', 0, 0, 0, 0, 0, 'none'),
#  ('Venezuela', 24, 22, 14, 40, 0, 'Rap'),
#  ('Vietnam', 13, 7, 1, 79, 0, 'Rap'),
#  ('Wallis & Futuna', 0, 0, 0, 0, 0, 'none'),
#  ('Western Sahara', 26, 30, 0, 44, 0, 'Rap'),
#  ('Yemen', 40, 35, 6, 19, 0, 'Rock'),
#  ('Zambia', 30, 15, 35, 15, 5, 'Instrumental'),
#  ('Zimbabwe', 39, 16, 24, 13, 8, 'Rock'),
#  ('Åland Islands', 72, 18, 0, 10, 0, 'Rock')]

# %% [markdown]
# The following results allowed us to view one of the 150 listed countries, and then see which genre of music was the most popular.
#
# As an analyst, I could show this data to the Music Business Development team so that they can have an idea of what genre of music appeals to each of these 250 countries. Since Facebook has users in nearly every single country, this data can help the partnership team target specific music labels and partners to promote specifically to users in that country.
#
#
# I then wanted to understand which genre of music was most popular all together based on the data of these countries. So I created a Common Table Expression to hold the results of our Case query, and then performed a count on the most_popular_genre_per_country column, using a WHERE statement to limit genre.

# %%
# %%sql
# WITH genre_ranking AS (
# SELECT geoName, Rock, Pop, Instrumental, Rap, RnB,
#     CASE
#         WHEN Rock>Pop AND Rock>Instrumental AND Rock>Rap AND Rock>RnB THEN "Rock"
#         WHEN Pop>Rock AND Pop>Instrumental AND Pop>Rap AND Pop>RnB THEN "Pop"
#         WHEN Instrumental>Rock AND Instrumental>Pop AND Instrumental>Rap AND Instrumental>RnB THEN "Instrumental"
#         WHEN Rap>Rock AND Rap>Pop AND Rap>Instrumental AND Rap>RnB THEN "Rap"
#         WHEN RnB>Rock AND RnB>Pop AND RnB>Instrumental AND RnB>Rap THEN "RnB"
#         ELSE "none"
#     END AS genre_ranking_by_country
# FROM popularity_by_country
# )
# SELECT COUNT(*)
# FROM genre_ranking
# WHERE genre_ranking_by_country = "Rock"
# Out:
#  * mysql://admin:***@lmu-sql.c8zmikzpsjej.us-east-2.rds.amazonaws.com/sql_project
# 1 rows affected.
# [(170,)]

# %% [markdown]
# The following query shows that the genre "Rock" is most popular in 170 countries. We will perform the same query to get a count for "Pop", "Instrumental", "Rap", "RnB", and "None" .

# %%
# %%sql
# WITH genre_ranking AS (
# SELECT geoName, Rock, Pop, Instrumental, Rap, RnB,
#     CASE
#         WHEN Rock>Pop AND Rock>Instrumental AND Rock>Rap AND Rock>RnB THEN "Rock"
#         WHEN Pop>Rock AND Pop>Instrumental AND Pop>Rap AND Pop>RnB THEN "Pop"
#         WHEN Instrumental>Rock AND Instrumental>Pop AND Instrumental>Rap AND Instrumental>RnB THEN "Instrumental"
#         WHEN Rap>Rock AND Rap>Pop AND Rap>Instrumental AND Rap>RnB THEN "Rap"
#         WHEN RnB>Rock AND RnB>Pop AND RnB>Instrumental AND RnB>Rap THEN "RnB"
#         ELSE "none"
#     END AS genre_ranking_by_country
# FROM popularity_by_country
# )
# SELECT COUNT(*)
# FROM genre_ranking
# WHERE genre_ranking_by_country = "Pop"
# Out:
#  * mysql://admin:***@lmu-sql.c8zmikzpsjej.us-east-2.rds.amazonaws.com/sql_project
# 1 rows affected.
# [(9,)]

# %%
# %%sql
# WITH genre_ranking AS (
# SELECT geoName, Rock, Pop, Instrumental, Rap, RnB,
#     CASE
#         WHEN Rock>Pop AND Rock>Instrumental AND Rock>Rap AND Rock>RnB THEN "Rock"
#         WHEN Pop>Rock AND Pop>Instrumental AND Pop>Rap AND Pop>RnB THEN "Pop"
#         WHEN Instrumental>Rock AND Instrumental>Pop AND Instrumental>Rap AND Instrumental>RnB THEN "Instrumental"
#         WHEN Rap>Rock AND Rap>Pop AND Rap>Instrumental AND Rap>RnB THEN "Rap"
#         WHEN RnB>Rock AND RnB>Pop AND RnB>Instrumental AND RnB>Rap THEN "RnB"
#         ELSE "none"
#     END AS genre_ranking_by_country
# FROM popularity_by_country
# )
# SELECT COUNT(*)
# FROM genre_ranking
# WHERE genre_ranking_by_country = "Instrumental"
# Out:
#  * mysql://admin:***@lmu-sql.c8zmikzpsjej.us-east-2.rds.amazonaws.com/sql_project
# 1 rows affected.
# [(10,)]

# %%
# %%sql
# WITH genre_ranking AS (
# SELECT geoName, Rock, Pop, Instrumental, Rap, RnB,
#     CASE
#         WHEN Rock>Pop AND Rock>Instrumental AND Rock>Rap AND Rock>RnB THEN "Rock"
#         WHEN Pop>Rock AND Pop>Instrumental AND Pop>Rap AND Pop>RnB THEN "Pop"
#         WHEN Instrumental>Rock AND Instrumental>Pop AND Instrumental>Rap AND Instrumental>RnB THEN "Instrumental"
#         WHEN Rap>Rock AND Rap>Pop AND Rap>Instrumental AND Rap>RnB THEN "Rap"
#         WHEN RnB>Rock AND RnB>Pop AND RnB>Instrumental AND RnB>Rap THEN "RnB"
#         ELSE "none"
#     END AS genre_ranking_by_country
# FROM popularity_by_country
# )
# SELECT COUNT(*)
# FROM genre_ranking
# WHERE genre_ranking_by_country = "Rap"
# Out:
#  * mysql://admin:***@lmu-sql.c8zmikzpsjej.us-east-2.rds.amazonaws.com/sql_project
# 1 rows affected.
# [(38,)]

# %%
# %%sql
# WITH genre_ranking AS (
# SELECT geoName, Rock, Pop, Instrumental, Rap, RnB,
#     CASE
#         WHEN Rock>Pop AND Rock>Instrumental AND Rock>Rap AND Rock>RnB THEN "Rock"
#         WHEN Pop>Rock AND Pop>Instrumental AND Pop>Rap AND Pop>RnB THEN "Pop"
#         WHEN Instrumental>Rock AND Instrumental>Pop AND Instrumental>Rap AND Instrumental>RnB THEN "Instrumental"
#         WHEN Rap>Rock AND Rap>Pop AND Rap>Instrumental AND Rap>RnB THEN "Rap"
#         WHEN RnB>Rock AND RnB>Pop AND RnB>Instrumental AND RnB>Rap THEN "RnB"
#         ELSE "none"
#     END AS genre_ranking_by_country
# FROM popularity_by_country
# )
# SELECT COUNT(*)
# FROM genre_ranking
# WHERE genre_ranking_by_country = "RnB"
# Out:
#  * mysql://admin:***@lmu-sql.c8zmikzpsjej.us-east-2.rds.amazonaws.com/sql_project
# 1 rows affected.
# [(0,)]

# %%
# %%sql
# WITH genre_ranking AS (
# SELECT geoName, Rock, Pop, Instrumental, Rap, RnB,
#     CASE
#         WHEN Rock>Pop AND Rock>Instrumental AND Rock>Rap AND Rock>RnB THEN "Rock"
#         WHEN Pop>Rock AND Pop>Instrumental AND Pop>Rap AND Pop>RnB THEN "Pop"
#         WHEN Instrumental>Rock AND Instrumental>Pop AND Instrumental>Rap AND Instrumental>RnB THEN "Instrumental"
#         WHEN Rap>Rock AND Rap>Pop AND Rap>Instrumental AND Rap>RnB THEN "Rap"
#         WHEN RnB>Rock AND RnB>Pop AND RnB>Instrumental AND RnB>Rap THEN "RnB"
#         ELSE "none"
#     END AS genre_ranking_by_country
# FROM popularity_by_country
# )
# SELECT COUNT(*)
# FROM genre_ranking
# WHERE genre_ranking_by_country = "None"
# Out:
#  * mysql://admin:***@lmu-sql.c8zmikzpsjej.us-east-2.rds.amazonaws.com/sql_project
# 1 rows affected.
# [(23,)]

# %% [markdown]
# The results conclude that Rock is the genre with most interest on Google Trends, with 170 countries ranking it as their top genre. Then Rap with 38, Instrumental with 10, Pop with 9, and RnB with 0.
#
# As an analyst sending this back to Music Business Development team, I would be able to use this data to show what genre most broadly appeals to a diverse range of people. Rock, in this case, seems to be universally popular and gets many searches. Let's imagine that the business development team is asked by the marketing team to provide ideas of what music to use in the back of a global commercial. They can refer to these results, or more specific monthly results, to see what is trending and will resonate best in a commercial.

# %% [markdown]
# # Exploratory Query 3

# %% [markdown]
# Can we find what genre of music various age groups are most interested in?
#
# To do so, we will use a subquery to compare each genre against the top genre for each age group.

# %%
# %%sql
# SELECT genre AS favorite_genre, max(16_19) AS percent_of_15_19_year_olds
# FROM genre_by_age_group
# WHERE 16_19 =
# 	(
# 		SELECT MAX(16_19)
# 		FROM genre_by_age_group);
# Out:
#  * mysql://admin:***@lmu-sql.c8zmikzpsjej.us-east-2.rds.amazonaws.com/sql_project
# 1 rows affected.
# [('Pop Music', 52)]

# %%
# %%sql
# SELECT genre AS favorite_genre, max(20_24) AS percent_of_20_24_year_olds
# FROM genre_by_age_group
# WHERE 20_24 =
# 	(
# 		SELECT MAX(20_24)
# 		FROM genre_by_age_group);
# Out:
#  * mysql://admin:***@lmu-sql.c8zmikzpsjej.us-east-2.rds.amazonaws.com/sql_project
# 1 rows affected.
# [('Pop Music', 54)]

# %%
# %%sql
# SELECT genre AS favorite_genre, max(25_34) AS percent_of_25_34_year_olds
# FROM genre_by_age_group
# WHERE 25_34 =
# 	(
# 		SELECT MAX(25_34)
# 		FROM genre_by_age_group);
# Out:
#  * mysql://admin:***@lmu-sql.c8zmikzpsjej.us-east-2.rds.amazonaws.com/sql_project
# 1 rows affected.
# [('Pop Music', 56)]

# %%
# %%sql
# SELECT genre AS favorite_genre, max(35_44) AS percent_of_35_44_year_olds
# FROM genre_by_age_group
# WHERE 35_44 =
# 	(
# 		SELECT MAX(35_44)
# 		FROM genre_by_age_group);
# Out:
#  * mysql://admin:***@lmu-sql.c8zmikzpsjej.us-east-2.rds.amazonaws.com/sql_project
# 1 rows affected.
# [('Pop Music', 46)]

# %%
# %%sql
# SELECT genre AS favorite_genre, max(45_54) AS percent_of_45_54_year_olds
# FROM genre_by_age_group
# WHERE 45_54 =
# 	(
# 		SELECT MAX(45_54)
# 		FROM genre_by_age_group);
# Out:
#  * mysql://admin:***@lmu-sql.c8zmikzpsjej.us-east-2.rds.amazonaws.com/sql_project
# 1 rows affected.
# [('Classic Rock', 62)]

# %%
# %%sql
# SELECT genre AS favorite_genre, max(55_64) AS percent_of_55_64_year_olds
# FROM genre_by_age_group
# WHERE 55_64 =
# 	(
# 		SELECT MAX(55_64)
# 		FROM genre_by_age_group);
# Out:
#  * mysql://admin:***@lmu-sql.c8zmikzpsjej.us-east-2.rds.amazonaws.com/sql_project
# 1 rows affected.
# [('Classic Rock', 60)]

# %%
# %%sql
#
# SELECT genre AS favorite_genre, max(65_up) AS percent_of_65_up_year_olds
# FROM genre_by_age_group
# WHERE 65_up =
# 	(
# 		SELECT MAX(65_up)
# 		FROM genre_by_age_group);
# Out:
#  * mysql://admin:***@lmu-sql.c8zmikzpsjej.us-east-2.rds.amazonaws.com/sql_project
# 1 rows affected.
# [('Classic Rock', 48)]

# %% [markdown]
# After running this query on all 7 age groups, the results are as follows:
# Pop is the most popular genre for age groups between 16 year old and 44.
# Classic Rock is the most popular genre for age groups 45-65 and up.
#
# Passing this data along the the Music Business Development Team will support them in their search for partnerships. They may consider using pop music advertisements or pop influencers for their younger demographic. They can use pop artists to market to younger users. The same applies to their older audience who prefers rock music. Additionally, the older audience had country/ western music as their second preferred genre, so using pop music ads or partnerships to appeal to these users may not be a smart move.
